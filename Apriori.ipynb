# %%
import pandas as pd
from itertools import combinations

# %% [markdown]
# ## Preprocessing

# %%
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
dataset = dataset.fillna(0)
transactions = []
for i in range(0, 7501):
    transactions.append([str(dataset.values[i, j]) for j in range(0, 20)])

# %%
def create_candidates(transactions, length):
    """Create initial candidate itemsets of length 1"""
    candidates = []
    for transaction in transactions:
        for item in transaction:
            if [item] not in candidates:
                candidates.append([item])
    candidates.sort()
    return list(map(frozenset, candidates))

# %%
def scan_database(transactions, candidates, min_support):
    """Scan the database and count the support of each candidate itemset"""
    itemset_counts = {}
    for transaction in transactions:
        for candidate in candidates:
            if candidate.issubset(transaction):
                itemset_counts[candidate] = itemset_counts.get(candidate, 0) + 1
    num_transactions = float(len(transactions))
    frequent_itemsets = []
    support_data = {}
    for itemset in itemset_counts:
        support = itemset_counts[itemset] / num_transactions
        if support >= min_support:
            frequent_itemsets.append(itemset)
        support_data[itemset] = support
    return frequent_itemsets, support_data

# %%
def generate_candidates(frequent_itemsets, length):
    """Generate candidate itemsets of length k from frequent itemsets of length k-1"""
    candidates = []
    num_frequent_itemsets = len(frequent_itemsets)
    for i in range(num_frequent_itemsets):
        for j in range(i + 1, num_frequent_itemsets):
            itemset1 = list(frequent_itemsets[i])[:length - 2]
            itemset2 = list(frequent_itemsets[j])[:length - 2]
            itemset1.sort()
            itemset2.sort()
            if itemset1 == itemset2:
                candidates.append(frequent_itemsets[i] | frequent_itemsets[j])
    return candidates

# %%
def apriori(transactions, min_support=0.5):
    """Apriori algorithm"""
    candidates = create_candidates(transactions, 1)
    frequent_itemsets1, support_data = scan_database(transactions, candidates, min_support)
    frequent_itemsets = [frequent_itemsets1]
    k = 2
    while len(frequent_itemsets[k - 2]) > 0:
        candidates = generate_candidates(frequent_itemsets[k - 2], k)
        frequent_itemsets_k, support_data_k = scan_database(transactions, candidates, min_support)
        support_data.update(support_data_k)
        frequent_itemsets.append(frequent_itemsets_k)
        k += 1
    return frequent_itemsets, support_data

# %% [markdown]
# ## Run Apriori algorithm

# %%
if __name__ == "__main__":
    frequent_itemsets, support_data = apriori(transactions, min_support=0.03)

    """Print results"""
    for i, itemset_list in enumerate(frequent_itemsets):
        print("Frequent itemsets of length {}: {}".format(i+1, len(itemset_list)))
        for itemset in itemset_list:
            print(itemset, "Support:", round(support_data[itemset], 4))
# Out:
# Frequent itemsets of length 1: 37
# frozenset({'avocado'}) Support: 0.0333
# frozenset({'cottage cheese'}) Support: 0.0319
# frozenset({'frozen smoothie'}) Support: 0.0633
# frozenset({'green tea'}) Support: 0.1321
# frozenset({'honey'}) Support: 0.0475
# frozenset({'low fat yogurt'}) Support: 0.0765
# frozenset({'mineral water'}) Support: 0.2384
# frozenset({'olive oil'}) Support: 0.0659
# frozenset({'salmon'}) Support: 0.0425
# frozenset({'shrimp'}) Support: 0.0715
# frozenset({'tomato juice'}) Support: 0.0304
# frozenset({'0'}) Support: 0.9999
# frozenset({'burgers'}) Support: 0.0872
# frozenset({'eggs'}) Support: 0.1797
# frozenset({'turkey'}) Support: 0.0625
# frozenset({'milk'}) Support: 0.1296
# frozenset({'whole wheat rice'}) Support: 0.0585
# frozenset({'french fries'}) Support: 0.1709
# frozenset({'soup'}) Support: 0.0505
# frozenset({'frozen vegetables'}) Support: 0.0953
# frozenset({'spaghetti'}) Support: 0.1741
# frozenset({'cookies'}) Support: 0.0804
# frozenset({'cooking oil'}) Support: 0.0511
# frozenset({'champagne'}) Support: 0.0468
# frozenset({'chicken'}) Support: 0.06
# frozenset({'chocolate'}) Support: 0.1638
# frozenset({'tomatoes'}) Support: 0.0684
# frozenset({'pancakes'}) Support: 0.0951
# frozenset({'grated cheese'}) Support: 0.0524
# frozenset({'fresh bread'}) Support: 0.0431
# frozenset({'escalope'}) Support: 0.0793
# frozenset({'ground beef'}) Support: 0.0983
# frozenset({'herb & pepper'}) Support: 0.0495
# frozenset({'cake'}) Support: 0.0811
# frozenset({'hot dogs'}) Support: 0.0324
# frozenset({'brownies'}) Support: 0.0337
# frozenset({'butter'}) Support: 0.0301
# Frequent itemsets of length 2: 54
# frozenset({'green tea', 'mineral water'}) Support: 0.0311
# frozenset({'burgers', '0'}) Support: 0.0872
# frozenset({'eggs', '0'}) Support: 0.1797
# frozenset({'avocado', '0'}) Support: 0.0332
# frozenset({'turkey', '0'}) Support: 0.0625
# frozenset({'green tea', '0'}) Support: 0.132
# frozenset({'mineral water', '0'}) Support: 0.2382
# frozenset({'milk', 'mineral water'}) Support: 0.048
# frozenset({'milk', '0'}) Support: 0.1296
# frozenset({'whole wheat rice', '0'}) Support: 0.0585
# frozenset({'low fat yogurt', '0'}) Support: 0.0764
# frozenset({'french fries', '0'}) Support: 0.1709
# frozenset({'soup', '0'}) Support: 0.0505
# frozenset({'frozen vegetables', '0'}) Support: 0.0953
# frozenset({'spaghetti', '0'}) Support: 0.1741
# frozenset({'cookies', '0'}) Support: 0.0804
# frozenset({'eggs', 'mineral water'}) Support: 0.0509
# frozenset({'cooking oil', '0'}) Support: 0.0511
# frozenset({'champagne', '0'}) Support: 0.0468
# frozenset({'salmon', '0'}) Support: 0.0424
# frozenset({'honey', '0'}) Support: 0.0473
# frozenset({'shrimp', '0'}) Support: 0.0713
# frozenset({'chicken', '0'}) Support: 0.06
# frozenset({'chocolate', '0'}) Support: 0.1638
# frozenset({'spaghetti', 'mineral water'}) Support: 0.0597
# frozenset({'tomatoes', '0'}) Support: 0.0684
# frozenset({'eggs', 'spaghetti'}) Support: 0.0365
# frozenset({'chocolate', 'eggs'}) Support: 0.0332
# frozenset({'pancakes', 'mineral water'}) Support: 0.0337
# frozenset({'pancakes', '0'}) Support: 0.0951
# frozenset({'grated cheese', '0'}) Support: 0.0524
# frozenset({'fresh bread', '0'}) Support: 0.0431
# frozenset({'milk', 'spaghetti'}) Support: 0.0355
# frozenset({'0', 'frozen smoothie'}) Support: 0.0632
# frozenset({'ground beef', 'mineral water'}) Support: 0.0409
# frozenset({'escalope', '0'}) Support: 0.0793
# frozenset({'ground beef', '0'}) Support: 0.0983
# frozenset({'ground beef', 'spaghetti'}) Support: 0.0392
# frozenset({'french fries', 'mineral water'}) Support: 0.0337
# frozenset({'chocolate', 'mineral water'}) Support: 0.0527
# frozenset({'eggs', 'french fries'}) Support: 0.0364
# frozenset({'chocolate', 'french fries'}) Support: 0.0344
# frozenset({'frozen vegetables', 'mineral water'}) Support: 0.0357
# frozenset({'herb & pepper', '0'}) Support: 0.0495
# frozenset({'cottage cheese', '0'}) Support: 0.0317
# frozenset({'cake', '0'}) Support: 0.0811
# frozenset({'hot dogs', '0'}) Support: 0.0324
# frozenset({'brownies', '0'}) Support: 0.0337
# frozenset({'chocolate', 'spaghetti'}) Support: 0.0392
# frozenset({'olive oil', '0'}) Support: 0.0657
# frozenset({'milk', 'chocolate'}) Support: 0.0321
# frozenset({'butter', '0'}) Support: 0.0301
# frozenset({'milk', 'eggs'}) Support: 0.0308
# frozenset({'tomato juice', '0'}) Support: 0.0303
# Frequent itemsets of length 3: 18
# frozenset({'green tea', 'mineral water', '0'}) Support: 0.0309
# frozenset({'milk', 'mineral water', '0'}) Support: 0.048
# frozenset({'eggs', 'mineral water', '0'}) Support: 0.0509
# frozenset({'eggs', 'spaghetti', '0'}) Support: 0.0365
# frozenset({'spaghetti', 'mineral water', '0'}) Support: 0.0597
# frozenset({'chocolate', 'eggs', '0'}) Support: 0.0332
# frozenset({'pancakes', 'mineral water', '0'}) Support: 0.0337
# frozenset({'milk', 'spaghetti', '0'}) Support: 0.0355
# frozenset({'ground beef', 'mineral water', '0'}) Support: 0.0409
# frozenset({'ground beef', 'spaghetti', '0'}) Support: 0.0392
# frozenset({'eggs', 'french fries', '0'}) Support: 0.0364
# frozenset({'french fries', 'mineral water', '0'}) Support: 0.0337
# frozenset({'chocolate', 'mineral water', '0'}) Support: 0.0527
# frozenset({'chocolate', 'french fries', '0'}) Support: 0.0344
# frozenset({'frozen vegetables', 'mineral water', '0'}) Support: 0.0357
# frozenset({'chocolate', 'spaghetti', '0'}) Support: 0.0392
# frozenset({'milk', 'chocolate', '0'}) Support: 0.0321
# frozenset({'milk', 'eggs', '0'}) Support: 0.0308
# Frequent itemsets of length 4: 0
